# %%
import akshare as ak
import pandas as pd
from myslide.main import StockDataProcessor

# %%
dp = StockDataProcessor()
# Out:
# 2025-09-15 16:56:06.757 | INFO     | myslide.main:__init__:30 - Output directory set to: reveal

# %%
dp.em_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dp.em_df
#
# AttributeError: 'StockDataProcessor' object has no attribute 'em_df'
