# %%
import pandas as pd
import akshare as ak
from plotnine import ggplot, aes, geom_bar, labs, theme_bw, theme_tufte, geom_density, geom_histogram
from plotnine.data import penguins
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

# 设置全局中文字体（在导入后立即设置）
font_path = '/usr/share/fonts/wenquanyi/wqy-microhei/wqy-microhei.ttc'
font_manager.fontManager.addfont(font_path)
plt.rcParams['font.family'] = font_manager.FontProperties(fname=font_path).get_name()

# %%
from plotnine import theme_set, theme, element_text
theme_set(theme(text=element_text(family='WenQuanYi Micro Hei')))  # 所有图表默认用雅黑

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['WenQuanYi Micro Hei']

# %%
df = ak.stock_zh_a_spot_em()
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]

# %%
print("当前默认字体:", plt.rcParams['font.family'])
# Out:
# 当前默认字体: ['WenQuanYi Micro Hei']

# %%
# '(0: 序号),(1: 代码),(2: 名称),(3: 最新价),(4: 涨跌幅),(5: 涨跌额),(6: 成交量),(7: 成交额),(8: 振幅),(9: 最高),(10: 最低),(11: 今开),(12: 昨收),(13: 量比),(14: 换手率),(15: 市盈率-动态),(16: 市净率),(17: 总市值),(18: 流通市值),(19: 涨速),(20: 5分钟涨跌),(21: 60日涨跌幅),(22: 年初至今涨跌幅)'
cols = df.columns

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the Axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the Axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the Axes.
ax.set_ylabel('y label')  # Add a y-label to the Axes.
ax.set_title("简单的测试")  # Add a title to the Axes.
ax.legend()  # Add a legend.
plt.show()

# %%
sel = df.iloc[:,[ 2,4,15,16,17]].dropna(how='any')
sel['总市值'] = (sel['总市值'].rank(pct=True) * 100).round(2)
sel_large = sel.nlargest(50, sel.columns[1])

# %%
Index(['名称', '涨跌幅', '市盈率-动态', '市净率', '总市值'], dtype='object')
sel.columns
# Out:
# Index(['名称', '涨跌幅', '市盈率-动态', '市净率', '总市值'], dtype='object')
